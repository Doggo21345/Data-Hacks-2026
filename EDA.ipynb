# %% [markdown]
# EDA and getting ready for Data Hacks 2026

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pylab as plt 
plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)
pd.set_option()
df =  pd.read_csv('/Users/aryapanda/Data Hacks 2026/coaster_db.csv')

# %% [markdown]
# Data Understanding

# %%
df.shape
# Out:
# (1087, 56)

# %%
df.head(5)

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                         str
# Length                               str
# Speed                                str
# Location                             str
# Status                               str
# Opening date                         str
# Type                                 str
# Manufacturer                         str
# Height restriction                   str
# Model                                str
# Height                               str
# Inversions                       float64
# Lift/launch system                   str
# Cost                                 str
# Trains                               str
# Park section                         str
# Duration                             str
# Capacity                             str
# G-force                              str
# Designer                             str
# Max vertical angle                   str
# Drop                                 str
# Soft opening date                    str
# ...

# %%
df.describe()

# %% [markdown]
# Data prep

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df[[''
'']].copy()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df[[''
#       2 '']]
#
# File ~/Data Hacks 2026/.venv/lib/python3.12/site-packages/pandas/core/frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File ~/Data Hacks 2026/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
pd.todatetime() # converts over to a Date object
pd.to_numeric() # converts over to a numeric object

# %%
df.rename(columns = {'old_nane': 'new_name'})

# %% [markdown]
# Missing values

# %%
df.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df.isna.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
df.duplicated() #will give us all of the duplicates but not the first instance of when this will be a duplicate

# %%
df.loc[df.duplictaed()] # this will then allow us to see what specifc values in our DF are duplicated

# %% [markdown]
# Feature understanding
# Univariate analysis

# %%
for col in df.columns: 
    df[].value_counts().head() # allows us to see the top 10 values for each column here 

for col in df.columns: 
    df[].value_counts().head().plot(kind = 'bar', title = 'titile') # allows us to see the top 10 values for each column here

# %%
ax = df[col].plot(kind = 'hist', bins = 20, titl  e = 'thing') #whenever we want to have the ax we wouild do this when we want to manipulate with matplot later for this

# %%
ax = df['col'].plot(kind = 'kde')

# %% [markdown]
# Feature Understanding
# - Scatter plots
# - Correlational matrix
# - Pairplot

# %%
sns.scatterplot() # more advanced thigns like hue and other things that are better for this

# %% [markdown]
# sns.pairplot() # will how each column interact with each other
